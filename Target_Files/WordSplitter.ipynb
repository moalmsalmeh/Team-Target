# %%
personTweets=[]
groupTweets=[]
publicTweets=[]

personFile = open('targetPersonTweets.txt', 'r', encoding="utf-8")
temp = personFile.readlines()
for line in temp:
    personTweets.append(str(line.replace(" \n", "")).lower())
    
groupFile = open('targetGroupTweets.txt', 'r', encoding="utf-8")
temp = groupFile.readlines()
for line in temp:
    groupTweets.append(str(line.replace(" \n", "")).lower())

publicFile = open('targetPublicTweets.txt', 'r', encoding="utf-8")
temp = publicFile.readlines()
for line in temp:
    publicTweets.append(str(line.replace(" \n", "")).lower())

# %%
personWords=[]
groupWords=[]
publicWords=[]

# %%
print(len(personTweets))
print(len(groupTweets))
print(len(publicTweets))
# Out:
# 2854
# 3207
# 2020

# %%
for tweet in personTweets:
    personWords.append(tweet.split())
personWords = sum(personWords, [])

for tweet in groupTweets:
    groupWords.append(tweet.split())
groupWords = sum(groupWords, [])

for tweet in publicTweets:
    publicWords.append(tweet.split())
publicWords = sum(publicWords, [])

# %%
personUnique=[]
groupUnique=[]
publicUnique=[]

# %%
for word in personWords:
    if word not in personUnique:
        personUnique.append(word)
        
for word in groupWords:
    if word not in groupUnique:
        groupUnique.append(word)
        
for word in publicWords:
    if word not in publicUnique:
        publicUnique.append(word)

# %%
print(len(personUnique))
print(len(groupUnique))
print(len(publicUnique))
# Out:
# 12334
# 13339
# 9859

# %%
#Wörter, die NUR in Person sind UND NICHT in Group ODER Public
onlyPerson=[]

for word in personUnique:
    if word not in groupUnique:
        if word not in publicUnique:
            onlyPerson.append(word)
        
print(len(onlyPerson))
# Out:
# 5416

# %%
#Test, ob onlyPerson wirklich nur Wörter hat, die weder in groupUnique, noch in publicUnique vorkommen
wordFound=False

for word in onlyPerson:
    if word in groupUnique:
        wordFound=True
    if word in publicUnique:
        wordFound=True
        
if wordFound is True:
    print("Wort ist nicht einzigartig!")
else:
    print(onlyPerson)
# Out:
# ['kackbraune', 'übermalen', 'chruppala', 'erderhitzung', 'hemlut', 'verstrahlter', 'egozentrischer', 'genießt', 'erträgt', 'todesengel', 'mengele', 'nigeria', 'mningitis', 'ausbrach', 'humanitärer', 'verdeckt', 'testmedikamente', 'ausprobiert', 'emo', 'drogensüchtige', 'assis', 'sticker', 'prolligen', 'beabsichtigt', 'genausogut', 'billigend', 'sek', 'spleenig', 'vov', 'fundierte', 'gegenseite', 'nichmehr', 'hernehmen', 'verbinden', 'gleichgeschlechtliche', 'nährstoffreiche', 'ernährung', 'hexenwerk', 'umgestellt', 'unertls', 'vogelscheuche', 'einwilligen', 'arabischer', 'durchschnittsalter', 'come', 'rhineland', 'palatinate', 'where', 'milk', 'flows', 'wisdom', 'queen', 'rules', 'englisch', 'ulkig', 'karlsruhe', 'erneuerbare', 'methan', 'agrarwende', 'energiedämmung', 'höherer', 'spritpreis', 'straßenpanzer', 'kerosinsteuer', 'inlandsflüge', 'bahnausbau', 'vermummten', 'randalieren', 'anzünden', 'scheiben', 'einschmeißen', 'wände', 'schmieren', 'mitteilen', 'zerstörungsbande', 'eeg', 'renaturierung', 'moore', 'vernässen', 'artenkollaps', 'flugverbotszonen', 'fußballstadien', 'schwerwiegende', 'verzweifelter', 'missachtung', 'unterrichten', 'hauptbewohner', 'torah', 'dreimal', 'kanns', 'notfallzulassung', 'unbeabsichtigte', 'falschanwendung', 'sippehaft', 'angriffsfläche', 'andreas', 'übler', 'looser', 'bundesministerien', 'praktiziert', 'bundesministerium', 'thursdayforhealth', 'monday', 'tuesday', 'linksterrorismus', 'wohlstandslinken', 'ausgrenzende', 'revolte', 'sämtlichen', 'omas', 'twitterusern', 'verspüre', 'home', 'wrong', 'diskrminalisirung', 'menschenhändler', 'dummshit', 'kopfschmerzen', 'müdigkeit', 'schlaflosigkeit', 'signifikanter', 'dürfens', 'think', 'hunderten', 'landtages', 'sacken', 'halbwissen', 'mittelfristig', 'flieger', 'impfflicht', 'esel', 'nachziehen', 'protzt', 'roulette', 'naturwissenschaften', 'stärke', 'steige', 'hoffnungslose', 'infantil', 'losgeht', 'führungspersonal', 'grundehrlich', 'schaumschläger', 'ausgespart', 'erschütterung', 'personenschutz', 'unperson', 'nachprüfen', 'fachwissen', 'höflich', 'hysteterische', 'kreischt', 'nettolohn', 'spanier', 'sommerhalbjahr', 'erhöhte', 'meltem', 'missgendert', 'transphoben', 'raushaut', 'fridaysforfurture', 'fernsehen', 'bekennen', 'insbes', 'scharfe', 'abgrenzung', 'transsexueller', 'transformation', 'hinzustellen', 'hineinziehen', 'angebrachte', 'begünstigt', 'dauerkriminelle', 'staatfinanzierter', 'infame', 'bedouine', 'sicherheitsbericht', 'zerlegen', 'raffgierige', 'barrikaden', 'revolutionären', 'verdächtigung', 'sauer', 'gondosch', 'mittelbach', 'schenk', 'fckfdp', 'reinkultur', 'analog', 'pinocchiopartei', 'verweigerer', 'dummtorten', 'moralischer', 'aufspielen', 'eissorten', 'erdbeere', 'verdien', 'einf', 'klatsche', 'chaoten', 'gläubig', 'aufgeilt', 'schreiber', 'vernetzt', 'erwähnen', 'ausgelastet', 'gemeldeten', 'passive', 'gentechnische', 'regeneron', 'streng', 'regulierten', 'gesellschaften', 'morning', 'diavolo', 'ernährt', 'unwissen', 'wärmt', 'err', 'krankenkassenleistungen', 'beruhen', 'saarland', 'meldedatum', 'verm', 'langes', 'aufrichtig', 'respektvoll', 'alledem', 'brandybrandner', 'byebyeafd', 'wendt', 'partein', 'patriotin', 'fahre', 'leerlauf', 'vollgas', 'auslaufmodell', 'fieser', 'hipster', 'appeasement', 'hausinternen', 'bezirken', 'weggekuschelt', 'ufo', 'wish', 'goldene', 'sido', 'wasserkopf', 'style', 'fashionlinie', 'logos', 'songtitel', 'putzfrau', 'selbstständig', 'arbeitend', 'freundlichem', 'hambacher', 'forst', 'klimaaktivisten', 'brutalster', 'baumhäusern', 'rwe', 'fossile', 'energieträger', 'fühlte', 'giftige', 'schoitel', 'hexer', 'dosko', 'strunzdumm', 'meter', 'pappn', 'perfekter', 'nordstrand', 'pharisäerhof', 'einmaliger', 'wohlfühlort', 'verunglimpfen', 'mitbürger', 'beteiligst', 'fällige', 'rosskur', 'wolkenkuckucksheimer', 'dummerweise', 'hennigwellsow', 'weltkriege', 'ideologen', 'deutschlandfeinden', 'antibiotikum', 'schmerzmittel', 'narkosemittel', 'fei', 'heterosexuellen', 'dysfunctional', 'administr ...

# %%
#Wörter, die NUR in Group sind UND NICHT in Person ODER Public
onlyGroup=[]

for word in groupUnique:
    if word not in personUnique:
        if word not in publicUnique:
            onlyGroup.append(word)
        
print(len(onlyGroup))
# Out:
# 6318

# %%
#Test, ob onlyGroup wirklich nur Wörter hat, die weder in personUnique, noch in publicUnique vorkommen
wordFound=False

for word in onlyGroup:
    if word in personUnique:
        wordFound=True
    if word in publicUnique:
        wordFound=True
        
if wordFound is True:
    print("Wort ist nicht einzigartig!")
else:
    print(onlyGroup)
# Out:
# ['eigentumswohnungen', 'ingenieur', 'schlaumeier', 'erzählst', 'demütigend', 'belagern', 'provozieren', 'absprechen', 'sekunde', 'ot', 'rfh', 'ereignissen', 'widerstands', 'infostände', 'barmbeker', 'ini', 'bergedorfer', 'völkerverständigung', 'linksjugend', 'solid', 'volksinitiative', 'ak', 'krisengebiete', 'duo', 'bundestagswahlkampf', 'hattet', 'fussballspiel', 'paris', 'kalashnikov', 'handgranaten', 'tatp', 'zeitgleich', 'bataclan', 'angstargumente', 'sachargumente', 'letztendlich', 'lobbyieren', 'betrügen', 'grosse', 'vorwirftst', 'aggression', 'rohr', 'normalisieren', 'mancher', 'kapitel', 'tagsüber', 'durchgeführt', 'vollstes', 'ausspricht', 'verstörender', 'skala', 'unzähligen', 'vertriebenen', 'lebensgrundlage', 'beraubten', 'hasswelle', 'kritikwürdige', 'mutige', 'kaufmanns', 'brandners', 'reinzuziehen', 'entlarven', 'großunternehmen', 'familienunternehmen', 'drückenden', 'steuerlast', 'entlassen', 'konkurs', 'verstorben', 'bürgerbeteiligung', 'lockerung', 'bar', 'erneuter', 'schließung', 'handbuch', 'polizeistaat', 'abgehalfterte', 'bekanntere', 'hingegeben', 'außendarstellung', 'totaler', 'bildungseinrichtungen', 'effiziente', 'pissnelke', 'heuchlerisches', 'hinterrücks', 'kriegstreiber', 'apropo', 'spannt', 'überraschend', 'möchtegerndenker', 'staatssekretärinnen', 'lesetipp', 'unsagbar', 'zulauf', 'ernstgemeint', 'broschüren', 'schlechthin', 'verpisst', 'schöneres', 'geringere', 'abgaben', 'idealziel', 'auszudrücken', 'armada', 'lügentrollen', 'beeinflussen', 'angreifer', 'parselmouth', 'verläßt', 'knipst', 'neurotiker', 'gestörtes', 'wegwerfen', 'persiflage', 'privilegierten', 'liebhabern', 'antidemokratische', 'anschuldigungen', 'vorhält', 'rückständig', 'medienblase', 'lebensrealität', 'inneren', 'bezwingen', 'optimierte', 'herangezogen', 'erstere', 'mäuler', 'stopfen', 'gentechnik', 'asi', 'testcenters', 'vorgezogen', 'individuell', 'friedlichen', 'reinste', 'horror', 'gesellschaftsfähig', 'sympathie', 'attestieren', 'verzeihbare', 'lehrkräfte', 'schülerinnen', 'unfassbares', 'waldgermane', 'umsturz', 'postwendend', 'rädelsführer', 'fragwürdigerweise', 'bannmeile', 'reichstagssturm', 'anfänglich', 'destruktiv', 'gesundheitsgefährdend', 'anwesenden', 'boshafte', 'artzhelferin', 'sportfest', 'erwartenden', 'menschenquälerrei', 'phosphorgranaten', 'draufschmeißen', 'schulte', 'demaskiert', 'ansar', 'thorstenschulte', 'ansarberlin', 'aaah', 'langzeittoten', 'erschieße', 'installierter', 'aufwachen', 'trau', 'harz', 'inzidenzwertgrenze', 'ross', 'arbeitgebern', 'aufrechnen', 'em', 'großmäulige', 'mißbraucht', 'wiederlege', 'schießsbefehl', 'schwurbelst', 'anschauungobjekt', 'spitzenpolitiker', 'nichtsnutze', 'gebauchpinselt', 'opfert', 'opferrolle', 'on', 'fleek', 'verarschen', 'ansprache', 'justiziable', 'wohnzimmer', 'satan', 'gruselt', 'handsymbol', 'ansteckungsgefahr', 'migrantin', 'dillidalli', 'herunterfährt', 'geistert', 'verständlichen', 'realitätscheck', 'moskau', 'passender', 'profiteure', 'ablegen', 'entfesselung', 'zukunftsmodell', 'ackern', 'laviert', 'kapital', 'draus', 'fangtendlichan', 'corrupte', 'gelben', 'marktjünger', 'aufführt', 'klimaextreme', 'vaters', 'brumm', 'vernebelten', 'heucherlich', 'querde', 'äusserungen', 'gs', 'tierisch', 'mittelalteransichten', 'vergrabt', 'bildungsland', 'hightech', 'studienplätze', 'professuren', 'ki', 'international', 'anerkannt', 'homophober', 'entgleisung', 'geprägt', 'überm', 'hochkochenden', 'beschreibst', 'ministerien', 'erbringung', 'hexen', 'verwunderlich', 'rutscht', 'virologie', 'epidemiologie', 'vorindustriellen', 'bevölkerungszahl', 'klimaschutzes', 'effizienz', 'naturbelassene', 'flächen', 'maximieren', 'part', 'qualifizierter', 'verfickten', 'werteverteter', 'fisten', 'richard', 'david', 'schwuchtelbinde', 'genossinnen', 'weltherrschaft', 'verkünden', 'ferkel', 'königin', 'dssr', 'basisdemokratie', 'lauterbachs', 'runawayalice', 'alias', 'tb', 'nutzbare', 'sportflächen', 'kontaktlos', 'geteilte', 'sportgeräte', 'derartige', 'vorfälle', 'personalqu ...

# %%
#Wörter, die NUR in Public sind UND NICHT in Person ODER Group
onlyPublic=[]

for word in publicUnique:
    if word not in personUnique:
        if word not in groupUnique:
            onlyPublic.append(word)
        
print(len(onlyPublic))
# Out:
# 3734

# %%
#Test, ob onlyPublic wirklich nur Wörter hat, die weder in personUnique, noch in groupUnique vorkommen
wordFound=False

for word in onlyPublic:
    if word in personUnique:
        wordFound=True
    if word in groupUnique:
        wordFound=True
        
if wordFound is True:
    print("Wort ist nicht einzigartig!")
else:
    print(onlyGroup)
# Out:
# ['eigentumswohnungen', 'ingenieur', 'schlaumeier', 'erzählst', 'demütigend', 'belagern', 'provozieren', 'absprechen', 'sekunde', 'ot', 'rfh', 'ereignissen', 'widerstands', 'infostände', 'barmbeker', 'ini', 'bergedorfer', 'völkerverständigung', 'linksjugend', 'solid', 'volksinitiative', 'ak', 'krisengebiete', 'duo', 'bundestagswahlkampf', 'hattet', 'fussballspiel', 'paris', 'kalashnikov', 'handgranaten', 'tatp', 'zeitgleich', 'bataclan', 'angstargumente', 'sachargumente', 'letztendlich', 'lobbyieren', 'betrügen', 'grosse', 'vorwirftst', 'aggression', 'rohr', 'normalisieren', 'mancher', 'kapitel', 'tagsüber', 'durchgeführt', 'vollstes', 'ausspricht', 'verstörender', 'skala', 'unzähligen', 'vertriebenen', 'lebensgrundlage', 'beraubten', 'hasswelle', 'kritikwürdige', 'mutige', 'kaufmanns', 'brandners', 'reinzuziehen', 'entlarven', 'großunternehmen', 'familienunternehmen', 'drückenden', 'steuerlast', 'entlassen', 'konkurs', 'verstorben', 'bürgerbeteiligung', 'lockerung', 'bar', 'erneuter', 'schließung', 'handbuch', 'polizeistaat', 'abgehalfterte', 'bekanntere', 'hingegeben', 'außendarstellung', 'totaler', 'bildungseinrichtungen', 'effiziente', 'pissnelke', 'heuchlerisches', 'hinterrücks', 'kriegstreiber', 'apropo', 'spannt', 'überraschend', 'möchtegerndenker', 'staatssekretärinnen', 'lesetipp', 'unsagbar', 'zulauf', 'ernstgemeint', 'broschüren', 'schlechthin', 'verpisst', 'schöneres', 'geringere', 'abgaben', 'idealziel', 'auszudrücken', 'armada', 'lügentrollen', 'beeinflussen', 'angreifer', 'parselmouth', 'verläßt', 'knipst', 'neurotiker', 'gestörtes', 'wegwerfen', 'persiflage', 'privilegierten', 'liebhabern', 'antidemokratische', 'anschuldigungen', 'vorhält', 'rückständig', 'medienblase', 'lebensrealität', 'inneren', 'bezwingen', 'optimierte', 'herangezogen', 'erstere', 'mäuler', 'stopfen', 'gentechnik', 'asi', 'testcenters', 'vorgezogen', 'individuell', 'friedlichen', 'reinste', 'horror', 'gesellschaftsfähig', 'sympathie', 'attestieren', 'verzeihbare', 'lehrkräfte', 'schülerinnen', 'unfassbares', 'waldgermane', 'umsturz', 'postwendend', 'rädelsführer', 'fragwürdigerweise', 'bannmeile', 'reichstagssturm', 'anfänglich', 'destruktiv', 'gesundheitsgefährdend', 'anwesenden', 'boshafte', 'artzhelferin', 'sportfest', 'erwartenden', 'menschenquälerrei', 'phosphorgranaten', 'draufschmeißen', 'schulte', 'demaskiert', 'ansar', 'thorstenschulte', 'ansarberlin', 'aaah', 'langzeittoten', 'erschieße', 'installierter', 'aufwachen', 'trau', 'harz', 'inzidenzwertgrenze', 'ross', 'arbeitgebern', 'aufrechnen', 'em', 'großmäulige', 'mißbraucht', 'wiederlege', 'schießsbefehl', 'schwurbelst', 'anschauungobjekt', 'spitzenpolitiker', 'nichtsnutze', 'gebauchpinselt', 'opfert', 'opferrolle', 'on', 'fleek', 'verarschen', 'ansprache', 'justiziable', 'wohnzimmer', 'satan', 'gruselt', 'handsymbol', 'ansteckungsgefahr', 'migrantin', 'dillidalli', 'herunterfährt', 'geistert', 'verständlichen', 'realitätscheck', 'moskau', 'passender', 'profiteure', 'ablegen', 'entfesselung', 'zukunftsmodell', 'ackern', 'laviert', 'kapital', 'draus', 'fangtendlichan', 'corrupte', 'gelben', 'marktjünger', 'aufführt', 'klimaextreme', 'vaters', 'brumm', 'vernebelten', 'heucherlich', 'querde', 'äusserungen', 'gs', 'tierisch', 'mittelalteransichten', 'vergrabt', 'bildungsland', 'hightech', 'studienplätze', 'professuren', 'ki', 'international', 'anerkannt', 'homophober', 'entgleisung', 'geprägt', 'überm', 'hochkochenden', 'beschreibst', 'ministerien', 'erbringung', 'hexen', 'verwunderlich', 'rutscht', 'virologie', 'epidemiologie', 'vorindustriellen', 'bevölkerungszahl', 'klimaschutzes', 'effizienz', 'naturbelassene', 'flächen', 'maximieren', 'part', 'qualifizierter', 'verfickten', 'werteverteter', 'fisten', 'richard', 'david', 'schwuchtelbinde', 'genossinnen', 'weltherrschaft', 'verkünden', 'ferkel', 'königin', 'dssr', 'basisdemokratie', 'lauterbachs', 'runawayalice', 'alias', 'tb', 'nutzbare', 'sportflächen', 'kontaktlos', 'geteilte', 'sportgeräte', 'derartige', 'vorfälle', 'personalqu ...

# %%
with open('onlyPersonWords.txt', 'w', encoding="utf-8") as f:
    for w in onlyPerson:
        f.writelines(str(w) + "\n")
with open('onlyGroupWords.txt', 'w', encoding="utf-8") as f:
    for w in onlyGroup:
        f.writelines(str(w) + "\n")
with open('onlyPublicWords.txt', 'w', encoding="utf-8") as f:
    for w in onlyPublic:
        f.writelines(str(w) + "\n")
